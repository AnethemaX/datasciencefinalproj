# %%
import pandas as pd
import numpy as np
import scipy
from scipy import stats as st
from scipy import cluster
from scipy import linalg as la
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.mlab import PCA
import pylab
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\Pavilion\Downloads\abalone.data.csv')
df.columns = ['Sex','Length','Diameter','Height','Whole Weight','Shucked Weight','Viscera Weight', 'Shell Weight', 'Rings']
df
# Out:
#      Sex  Length  Diameter  Height  Whole Weight  Shucked Weight  \
# 0      M   0.350     0.265   0.090        0.2255          0.0995
# 1      F   0.530     0.420   0.135        0.6770          0.2565
# 2      M   0.440     0.365   0.125        0.5160          0.2155
# 3      I   0.330     0.255   0.080        0.2050          0.0895
# 4      I   0.425     0.300   0.095        0.3515          0.1410
# 5      F   0.530     0.415   0.150        0.7775          0.2370
# 6      F   0.545     0.425   0.125        0.7680          0.2940
# 7      M   0.475     0.370   0.125        0.5095          0.2165
# 8      F   0.550     0.440   0.150        0.8945          0.3145
# 9      F   0.525     0.380   0.140        0.6065          0.1940
# 10     M   0.430     0.350   0.110        0.4060          0.1675
# 11     M   0.490     0.380   0.135        0.5415          0.2175
# 12     F   0.535     0.405   0.145        0.6845          0.2725
# ...

# %%
df['Age'] = np.nan
for i in range(len(df.index)):
     df.iat[i,9] = df.iat[i,8]+1.5
df
# Out:
#      Sex  Length  Diameter  Height  Whole Weight  Shucked Weight  \
# 0      M   0.350     0.265   0.090        0.2255          0.0995
# 1      F   0.530     0.420   0.135        0.6770          0.2565
# 2      M   0.440     0.365   0.125        0.5160          0.2155
# 3      I   0.330     0.255   0.080        0.2050          0.0895
# 4      I   0.425     0.300   0.095        0.3515          0.1410
# 5      F   0.530     0.415   0.150        0.7775          0.2370
# 6      F   0.545     0.425   0.125        0.7680          0.2940
# 7      M   0.475     0.370   0.125        0.5095          0.2165
# 8      F   0.550     0.440   0.150        0.8945          0.3145
# 9      F   0.525     0.380   0.140        0.6065          0.1940
# 10     M   0.430     0.350   0.110        0.4060          0.1675
# 11     M   0.490     0.380   0.135        0.5415          0.2175
# 12     F   0.535     0.405   0.145        0.6845          0.2725
# ...

# %%
df_length = df['Length']
df_diameter = df['Diameter']
df_height = df['Height']
df_wweight = df['Whole Weight']
df_sweight = df['Shucked Weight']
df_vweight = df['Viscera Weight']
df_shweight = df['Shell Weight']
df_ring = df['Rings']
df_age = df['Age']

# %%
slope, intercept, r_value, p_value, slope_std_error = st.linregress(df_wweight, df_sweight)
predict_y = intercept + slope * df_wweight
pred_error = df_sweight - predict_y
degrees_of_freedom = len(df_wweight) - 2
residual_std_error = np.sqrt(np.sum(pred_error**2) / degrees_of_freedom)
print(r_value, p_value)
pylab.plot(df_wweight, df_sweight, 'o')
pylab.plot(df_wweight, predict_y, 'k-')
pylab.show()
# Out:
# 0.969402734545 0.0

# %%
slope, intercept, r_value, p_value, slope_std_error = st.linregress(df_wweight, df_vweight)
predict_y = intercept + slope * df_wweight
pred_error = df_vweight - predict_y
degrees_of_freedom = len(df_wweight) - 2
residual_std_error = np.sqrt(np.sum(pred_error**2) / degrees_of_freedom)
print(r_value, p_value)
pylab.plot(df_wweight, df_vweight, 'o')
pylab.plot(df_wweight, predict_y, 'k-')
pylab.show()
# Out:
# 0.966372147113 0.0

# %%
slope, intercept, r_value, p_value, slope_std_error = st.linregress(df_wweight, df_shweight)
predict_y = intercept + slope * df_wweight
pred_error = df_shweight - predict_y
degrees_of_freedom = len(df_wweight) - 2
residual_std_error = np.sqrt(np.sum(pred_error**2) / degrees_of_freedom)
print(r_value, p_value)
pylab.plot(df_wweight, df_shweight, 'o')
pylab.plot(df_wweight, predict_y, 'k-')
pylab.show()
# Out:
# 0.955351063616 0.0

# %%
slope, intercept, r_value, p_value, slope_std_error = st.linregress(df_length, df_diameter)
predict_y = intercept + slope * df_length
pred_error = df_diameter - predict_y
degrees_of_freedom = len(df_length) - 2
residual_std_error = np.sqrt(np.sum(pred_error**2) / degrees_of_freedom)
print(r_value, p_value)
pylab.plot(df_length, df_diameter, 'o')
pylab.plot(df_length, predict_y, 'k-')
pylab.show()
# Out:
# 0.986813196884 0.0

# %%
slope, intercept, r_value, p_value, slope_std_error = st.linregress(df_length, df_height)
predict_y = intercept + slope * df_length
pred_error = df_height - predict_y
degrees_of_freedom = len(df_length) - 2
residual_std_error = np.sqrt(np.sum(pred_error**2) / degrees_of_freedom)
print(r_value, p_value)
pylab.plot(df_length, df_height, 'o')
pylab.plot(df_length, predict_y, 'k-')
pylab.show()
# Out:
# 0.827552135355 0.0

# %%
slope, intercept, r_value, p_value, slope_std_error = st.linregress(df_diameter, df_height)
predict_y = intercept + slope * df_diameter
pred_error = df_height - predict_y
degrees_of_freedom = len(df_diameter) - 2
residual_std_error = np.sqrt(np.sum(pred_error**2) / degrees_of_freedom)
print(r_value, p_value)
pylab.plot(df_diameter, df_height, 'o')
pylab.plot(df_diameter, predict_y, 'k-')
pylab.show()
# Out:
# 0.833705281486 0.0

# %%
slope, intercept, r_value, p_value, slope_std_error = st.linregress(df_length, df_age)
predict_y = intercept + slope * df_length
pred_error = df_age - predict_y
degrees_of_freedom = len(df_length) - 2
residual_std_error = np.sqrt(np.sum(pred_error**2) / degrees_of_freedom)
print(r_value, p_value)
pylab.plot(df_length, df_age, 'o')
pylab.plot(df_length, predict_y, 'k-')
pylab.show()
# Out:
# 0.557122583122 0.0

# %%
slope, intercept, r_value, p_value, slope_std_error = st.linregress(df_diameter, df_age)
predict_y = intercept + slope * df_diameter
pred_error = df_age - predict_y
degrees_of_freedom = len(df_diameter) - 2
residual_std_error = np.sqrt(np.sum(pred_error**2) / degrees_of_freedom)
print(r_value, p_value)
pylab.plot(df_diameter, df_age, 'o')
pylab.plot(df_diameter, predict_y, 'k-')
pylab.show()
# Out:
# 0.575005392928 0.0

# %%
slope, intercept, r_value, p_value, slope_std_error = st.linregress(df_height, df_age)
predict_y = intercept + slope * df_height
pred_error = df_age - predict_y
degrees_of_freedom = len(df_height) - 2
residual_std_error = np.sqrt(np.sum(pred_error**2) / degrees_of_freedom)
print(r_value, p_value)
pylab.plot(df_height, df_age, 'o')
pylab.plot(df_height, predict_y, 'k-')
pylab.show()
# Out:
# 0.55810865137 0.0

# %%
slope, intercept, r_value, p_value, slope_std_error = st.linregress(df_wweight, df_age)
predict_y = intercept + slope * df_wweight
pred_error = df_age - predict_y
degrees_of_freedom = len(df_wweight) - 2
residual_std_error = np.sqrt(np.sum(pred_error**2) / degrees_of_freedom)
print(r_value, p_value)
pylab.plot(df_wweight, df_age, 'o')
pylab.plot(df_wweight, predict_y, 'k-')
pylab.show()
# Out:
# 0.540817861629 0.0

# %%
slope, intercept, r_value, p_value, slope_std_error = st.linregress(df_vweight, df_age)
predict_y = intercept + slope * df_vweight
pred_error = df_age - predict_y
degrees_of_freedom = len(df_vweight) - 2
residual_std_error = np.sqrt(np.sum(pred_error**2) / degrees_of_freedom)
print(r_value, p_value)
pylab.plot(df_vweight, df_age, 'o')
pylab.plot(df_vweight, predict_y, 'k-')
pylab.show()
# Out:
# 0.504273515366 2.7543999151e-268

# %%
slope, intercept, r_value, p_value, slope_std_error = st.linregress(df_sweight, df_age)
predict_y = intercept + slope * df_sweight
pred_error = df_age - predict_y
degrees_of_freedom = len(df_sweight) - 2
residual_std_error = np.sqrt(np.sum(pred_error**2) / degrees_of_freedom)
print(r_value, p_value)
pylab.plot(df_sweight, df_age, 'o')
pylab.plot(df_sweight, predict_y, 'k-')
pylab.show()
# Out:
# 0.421255554113 2.53202255569e-179

# %%
slope, intercept, r_value, p_value, slope_std_error = st.linregress(df_shweight, df_age)
predict_y = intercept + slope * df_shweight
pred_error = df_age - predict_y
degrees_of_freedom = len(df_shweight) - 2
residual_std_error = np.sqrt(np.sum(pred_error**2) / degrees_of_freedom)
print(r_value, p_value)
pylab.plot(df_shweight, df_age, 'o')
pylab.plot(df_shweight, predict_y, 'k-')
pylab.show()
# Out:
# 0.628030584167 0.0
